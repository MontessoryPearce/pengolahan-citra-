# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt

img = cv2.imread('IB.png')

kernel = np.ones((5,5),np.float32)/25
dst = cv2.GaussianBlur(img,(5,5),0)


plt.subplot(121),plt.imshow(img),plt.title('Original')
plt.xticks([]), plt.yticks([])
plt.subplot(122),plt.imshow(dst),plt.title('Averaging')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
print(im2)
# Out:
# [[[116 129 127]
#   [115 128 126]
#   [115 128 126]
#   ...
#   [250 250 244]
#   [250 250 244]
#   [250 250 244]]
#
#  [[116 129 127]
#   [116 129 127]
#   [115 128 126]
#   ...
#   [250 250 244]
#   [250 250 244]
#   [250 250 244]]
#
#  [[117 130 128]
#   [116 129 127]
#   [116 129 127]
#   ...
#   [250 250 244]
#   [250 250 244]
#   [250 250 244]]
#
#  ...
#
#  [[211 195 149]
#   [209 193 147]
#   [206 190 148]
#   ...
#   [137 113  53]
#   [140 116  56]
#   [142 118  58]]
#
#  [[211 195 149]
#   [209 193 147]
#   [206 190 148]
#   ...
#   [136 115  54]
#   [139 118  57]
#   [141 120  59]]
#
#  [[211 195 149]
#   [209 193 147]
#   [206 190 148]
#   ...
#   [138 117  56]
#   [140 119  58]
#   [143 122  61]]]

# %%
import matplotlib.pyplot as plt
import numpy as np

filer = np.array([[-1,0,1],[-1,0,1]])
plt.imshow(filer)
plt.show()

# %%
baru = convolution(im2, filer)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-18-5f871537c97a> in <module>()
# ----> 1 baru = convolution(im2, filer)
#
# <ipython-input-5-c6c4aff9fe76> in convolution(oldimage, kernel)
#      23             #sum = 0
#      24             x = image_pad[i-h:i-h+kernel_h, j-w:j-w+kernel_w]
# ---> 25             x = x.flatten()*kernel.flatten()
#      26             image_conv[i][j] = x.sum()
#      27     h_end = -h
#
# ValueError: operands could not be broadcast together with shapes (18,) (6,)
